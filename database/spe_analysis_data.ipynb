# %%
import sqlalchemy as db
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base

# Connect to AWS database
database_url = f'postgresql://postgres:purifai2022@purifai.ceoinb9nwfxg.us-west-1.rds.amazonaws.com/postgres'
engine = db.create_engine(database_url)
connection = engine.connect()

# %%
with engine.connect() as conn:
    spe_analysis = conn.execute("SELECT * FROM outcomes INNER JOIN structures ON outcomes.structure_id = structures.structure_id WHERE spe_successful = 'true' ;")
                          
    # SET THE COLUMN NAMES and DATA CONTENTS
columns = [x for x in spe_analysis.keys()]
data = [x for x in spe_analysis]

# %%
print(data)
# Out:
# [('00YLL22-042-002', '00YLL22-042-002', 'Gemini LpH', 'MCX', 'MCX/Gemini LpH', 'true', None, 'Complete', 'Completed & Shipped', None, None, None, 0.1, 'F3L/F4S', 8.11, 1, 1.7, 0.0047, 0.0098, None, '00YLL22-042-002', 450.326, 449.1021449, 0.648315106, 83.46, 429.158, 2.7852, 114.4697, 0.35, 158, 0.248501459, -0.36181697, 1.233333333, 1.637090032, 1107.787679, -2.55, 8262449.833, 8.293416465, 182.8279928, 13.21376393, 14.68775618, 45.91916417, 0.0, 70.23250649, 24.52642128, 12.69436275, -0.184875241, 29.67953585, 14.76446326, 30, 1, 8, 0, 1, 1, 1, 2, 3, 5, 1, 10, 5, 0, 0, 0, 4), ('00YLL22-042-003', '00YLL22-042-003', 'Xbridge HpH', 'MCX', 'MCX/Xbridge HpH', 'true', None, 'Complete', 'Completed & Shipped', None, None, None, 0.1, 'F3L/F4S', 21.52, 1, 2.9, 0.0053, 0.01, None, '00YLL22-042-003', 446.338, 445.1072303, 0.654589732, 74.23, 425.17, 3.5488, 115.3177, 0.380952381, 156, 0.22739984, -0.344963648, 1.266666667, 1.554245709, 1154.313204, -2.51, 11726505.08, 7.320104163, 183.0735586, 0.0, 14.68775618, 45.91916417, 5.917906046, 56.51582698, 24.52642128, 13.26222934, -0.153670337, 49.0659355, 14.76446326, 30, 1, 7, 0, 2, 2, 1, 2, 3, 4, 1, 9, 2, 0, 1, 1, 5), ('00YLL22-042-004', '00YLL22-042-004', 'Xbridge HpH', 'MCX', 'MCX/Xbridge HpH', 'true', None, 'Complete', 'Completed & Shipped', None, None, None, 0.1, 'F3L', 14.57, 1, 22.8, 0.0042, 0.01, None, '00YLL22-042-004', 434.327, 433.1072303, 0.688605249, 66.39, 413.159, 3.011, 112.1937, 0.4, 152, 0.247809342, -0.376288852, 1.275862069, 1.63727147, 1102.217297, -2.06, 5160601.588, 6.736509708, 177.6606396, 5.538925252, 14.79312872, 40.01198444, 0.0, 69.86425201, 24.52642128, 13.41695157, -0.5784303, 42.89329977, 14.76446326, 29, 1, 7, 0, 2, 2, 1, 2, 3, 5, 1, 9, 3, 0, 1, 1, 5), ('00YLL22-042-005', '00YLL22-042-005', 'Xbridge HpH', 'MCX', 'MCX/Xbridge HpH', 'true', None, 'Complete', 'Completed & Shipped', None, None, None, 0.1, 'F3L/F1S', 19.08, 1, 18.0, None, 0.0099, None, '00YLL22-042-005', 447.326, 446.1024792, 0.670781537, 77.47, 427.166, 3.0478, 114.5557, 0.35, 156, 0.319835482, -0.339283845, 1.2, 1.521883007, 1156.213174, -2.71, 11909530.9, 7.210640342, 182.4684501, 6.544756406, 9.893218992, 46.04309895, 0.0, 74.6291843, 24.52642128, 12.9887146, -0.101867681, 42.76904866, 14.76446326, 30, 1, 8, 0, 2, 2, 1, 2, 3, 4, 1, 10, 3, 0, 1, 1, 5), ('00YLL22-042-008', '00YLL22-042-008', 'Xbridge HpH', 'MCX', 'MCX/Xbridge HpH', 'true', None, 'Complete', 'Completed & Shipped', None, None, None, 0.1, 'F3L', 14.49, 1, 25.7, None, 0.01, None, '00YLL22-042-008', 434.327, 433.1072303, 0.673754678, 66.39, 413.159, 3.011, 112.1937, 0.4, 152, 0.242227503, -0.377939186, 1.275862069, 1.596059393, 1078.666585, -2.06, 8111294.187, 7.322792019, 177.6606396, 6.041840829, 14.79312872, 40.01198444, 0.0, 69.86425201, 24.52642128, 13.23672008, -0.240661078, 42.89329977, 19.664373, 29, 1, 7, 0, 2, 2, 1, 2, 3, 5, 1, 9, 2, 0, 1, 1, 5), ('00YLL22-042-010', '00YLL22-042-010', 'Xbridge HpH', 'MCX', 'MCX/Xbridge HpH', 'true', None, 'Complete', 'Completed & Shipped', None, None, None, 0.1, 'F3L/F1S', 8.48, 1, 11.7, None, 0.0099, None, '00YLL22-042-010', 478.361, 477.0429158, 0.619230594, 91.3, 461.225, 3.7643, 119.1187, 0.3, 160, 0.288308874, -0.339283863, 1.290322581, 1.508697474, 1239.645243, -2.49, 17391987.18, 7.578012352, 190.9932486, 5.24993803, 24.38220309, 62.92026083, 0.0, 60.46022032, 24.52642128, 13.01241831, -0.667241033, 29.67953585, 14.76446326, 31, 1, 8, 0, 2, 2, 1, 2, 3, 6, 1, 11, 3, 0, 1, 1, 5), ('00YLL22-042-014', '00YLL22-042-014', 'Xbridge HpH', 'MCX', 'MCX/Xbridge HpH', 'true', None, 'Complete', 'Completed & Shipped', None, None, None, 0.1, 'F3L/F1S', 13.66, 1, 12.5, None, 0.01, None, '00YLL22-042-014', 446.338, 445.1072303, 0.667154151, 74.23, 425.17, 3.6913, 115.3657, 0.380952381, 156, 0.224555977, -0.342243608, 1.3, 1.52162409, 1154.313204, -2.51, 11909530.9, 7.320104163, 183.0735586, 0.0, 14.68775618, 45.91916417, 0.0, 56.0129114, 24.52642128, 13.06315527, -0.014463255, 42.52117909, 14.764463 ...

# %%
import pandas as pd

# write spe_analysis into pandas dataframe
spe_analysis_df = pd.DataFrame(data, columns=columns)
spe_analysis_df.head()
# Out:
#          sample_id     structure_id preferred_lcms_method spe_method  \
# 0  00YLL22-042-002  00YLL22-042-002            Gemini LpH        MCX
# 1  00YLL22-042-003  00YLL22-042-003           Xbridge HpH        MCX
# 2  00YLL22-042-004  00YLL22-042-004           Xbridge HpH        MCX
# 3  00YLL22-042-005  00YLL22-042-005           Xbridge HpH        MCX
# 4  00YLL22-042-008  00YLL22-042-008           Xbridge HpH        MCX
#
#             method spe_successful crashed_out sample_status  \
# 0   MCX/Gemini LpH           true        None      Complete
# 1  MCX/Xbridge HpH           true        None      Complete
# 2  MCX/Xbridge HpH           true        None      Complete
# 3  MCX/Xbridge HpH           true        None      Complete
# 4  MCX/Xbridge HpH           true        None      Complete
#
#   sample_current_status termination_cause  ... NumAromaticHeterocycles  \
# 0   Completed & Shipped              None  ...                       2
# 1   Completed & Shipped              None  ...                       2
# 2   Completed & Shipped              None  ...                       2
# 3   Completed & Shipped              None  ...                       2
# 4   Completed & Shipped              None  ...                       2
#
#   NumAromaticRings  NumHAcceptors NumHDonors  NumHeteroatoms  \
# 0                3              5          1              10
# 1                3              4          1               9
# 2                3              5          1               9
# 3                3              4          1              10
# 4                3              5          1               9
#
#    NumRotatableBonds  NumSaturatedCarbocycles  NumSaturatedHeterocycles  \
# 0                  5                        0                         0
# 1                  2                        0                         1
# 2                  3                        0                         1
# 3                  3                        0                         1
# 4                  2                        0                         1
#
#    NumSaturatedRings RingCount
# 0                  0         4
# 1                  1         5
# 2                  1         5
# 3                  1         5
# 4                  1         5
#
# [5 rows x 66 columns]

# %%
dict(spe_analysis_df.dtypes)
# Out:
# {'sample_id': dtype('O'),
#  'structure_id': structure_id    object
#  structure_id    object
#  dtype: object,
#  'preferred_lcms_method': dtype('O'),
#  'spe_method': dtype('O'),
#  'method': dtype('O'),
#  'spe_successful': dtype('O'),
#  'crashed_out': dtype('O'),
#  'sample_status': dtype('O'),
#  'sample_current_status': dtype('O'),
#  'termination_cause': dtype('O'),
#  'termination_step': dtype('O'),
#  'termination_details': dtype('O'),
#  'reaction_scale': dtype('float64'),
#  'selected_fractions': dtype('O'),
#  'volume_collected': dtype('float64'),
#  'total_fractions_collected': dtype('float64'),
#  'recovered_sample_dry_mass': dtype('float64'),
#  'percent_yield': dtype('float64'),
#  'percent_purity': dtype('float64'),
#  'purification_comments': dtype('O'),
#  'MolWt': dtype('float64'),
#  'exactMolWt': dtype('float64'),
#  'qed': dtype('float64'),
#  'TPSA': dtype('float64'),
#  'HeavyAtomMolWt': dtype('float64'),
#  'MolLogP': dtype('float64'),
#  'MolMR': dtype('float64'),
#  'FractionCSP3': dtype('float64'),
#  'NumValenceElectrons': dtype('int64'),
#  'MaxPartialCharge': dtype('float64'),
#  'MinPartialCharge': dtype('float64'),
#  'FpDensityMorgan1': dtype('float64'),
#  'BalabanJ': dtype('float64'),
#  'BertzCT': dtype('float64'),
#  'HallKierAlpha': dtype('float64'),
#  'Ipc': dtype('float64'),
#  'Kappa2': dtype('float64'),
#  'LabuteASA': dtype('float64'),
#  'PEOE_VSA10': dtype('float64'),
#  'PEOE_VSA2': dtype('float64'),
#  'SMR_VSA10': dtype('float64'),
#  'SMR_VSA4': dtype('float64'),
#  'SlogP_VSA2': dtype('float64'),
#  'SlogP_VSA6': dtype('float64'),
#  'MaxEStateIndex': dtype('float64'),
#  'MinEStateIndex': dtype('float64'),
#  'EState_VSA3': dtype('float64'),
#  'EState_VSA8': dtype('float64'),
#  'HeavyAtomCount': dtype('int64'),
#  'NHOHCount': dtype('int64'),
#  'NOCount': dtype('int64'),
#  'NumAliphaticCarbocycles': dtype('int64'),
#  'NumAliphaticHeterocycles': dtype('int64'),
#  'NumAliphaticRings': dtype('int64'),
#  'NumAromaticCarbocycles': dtype('int64'),
#  'NumAromaticHeterocycles': dtype('int64'),
#  'NumAromaticRings': dtype('int64'),
#  'NumHAcceptors': dtype('int64'),
#  'NumHDonors': dtype('int64'),
#  'NumHeteroatoms': dtype('int64'),
#  'NumRotatableBonds': dtype('int64'),
#  'NumSaturatedCarbocycles': dtype('int64'),
#  'NumSaturatedHeterocycles': dtype('int64'),
#  'NumSaturatedRings': dtype('int64'),
#  'RingCount': dtype('int64')}

# %%
# write spe_analysis into pandas dataframe
# spe_analysis_df.to_sql('spe_analysis', engine, if_exists='replace', index=False)

# %%
# list of name, degree, score 
df=pd.DataFrame(data, columns=columns)
dict(df.dtypes)
# Out:
# {'sample_id': dtype('O'),
#  'structure_id': structure_id    object
#  structure_id    object
#  dtype: object,
#  'preferred_lcms_method': dtype('O'),
#  'spe_method': dtype('O'),
#  'method': dtype('O'),
#  'spe_successful': dtype('O'),
#  'crashed_out': dtype('O'),
#  'sample_status': dtype('O'),
#  'sample_current_status': dtype('O'),
#  'termination_cause': dtype('O'),
#  'termination_step': dtype('O'),
#  'termination_details': dtype('O'),
#  'reaction_scale': dtype('float64'),
#  'selected_fractions': dtype('O'),
#  'volume_collected': dtype('float64'),
#  'total_fractions_collected': dtype('float64'),
#  'recovered_sample_dry_mass': dtype('float64'),
#  'percent_yield': dtype('float64'),
#  'percent_purity': dtype('float64'),
#  'purification_comments': dtype('O'),
#  'MolWt': dtype('float64'),
#  'exactMolWt': dtype('float64'),
#  'qed': dtype('float64'),
#  'TPSA': dtype('float64'),
#  'HeavyAtomMolWt': dtype('float64'),
#  'MolLogP': dtype('float64'),
#  'MolMR': dtype('float64'),
#  'FractionCSP3': dtype('float64'),
#  'NumValenceElectrons': dtype('int64'),
#  'MaxPartialCharge': dtype('float64'),
#  'MinPartialCharge': dtype('float64'),
#  'FpDensityMorgan1': dtype('float64'),
#  'BalabanJ': dtype('float64'),
#  'BertzCT': dtype('float64'),
#  'HallKierAlpha': dtype('float64'),
#  'Ipc': dtype('float64'),
#  'Kappa2': dtype('float64'),
#  'LabuteASA': dtype('float64'),
#  'PEOE_VSA10': dtype('float64'),
#  'PEOE_VSA2': dtype('float64'),
#  'SMR_VSA10': dtype('float64'),
#  'SMR_VSA4': dtype('float64'),
#  'SlogP_VSA2': dtype('float64'),
#  'SlogP_VSA6': dtype('float64'),
#  'MaxEStateIndex': dtype('float64'),
#  'MinEStateIndex': dtype('float64'),
#  'EState_VSA3': dtype('float64'),
#  'EState_VSA8': dtype('float64'),
#  'HeavyAtomCount': dtype('int64'),
#  'NHOHCount': dtype('int64'),
#  'NOCount': dtype('int64'),
#  'NumAliphaticCarbocycles': dtype('int64'),
#  'NumAliphaticHeterocycles': dtype('int64'),
#  'NumAliphaticRings': dtype('int64'),
#  'NumAromaticCarbocycles': dtype('int64'),
#  'NumAromaticHeterocycles': dtype('int64'),
#  'NumAromaticRings': dtype('int64'),
#  'NumHAcceptors': dtype('int64'),
#  'NumHDonors': dtype('int64'),
#  'NumHeteroatoms': dtype('int64'),
#  'NumRotatableBonds': dtype('int64'),
#  'NumSaturatedCarbocycles': dtype('int64'),
#  'NumSaturatedHeterocycles': dtype('int64'),
#  'NumSaturatedRings': dtype('int64'),
#  'RingCount': dtype('int64')}
