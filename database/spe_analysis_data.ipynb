# %%
import sqlalchemy as db
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base

# Connect to AWS database
database_url = f'postgresql://postgres:purifai2022@purifai.ceoinb9nwfxg.us-west-1.rds.amazonaws.com/postgres'
engine = db.create_engine(database_url)
connection = engine.connect()

# %%
with engine.connect() as conn:
    spe_analysis = conn.execute("SELECT * FROM outcomes INNER JOIN structures ON outcomes.structure_id = structures.structure_id WHERE spe_successful = 'TRUE' ;")
                          
    # SET THE COLUMN NAMES and DATA CONTENTS
columns = [x for x in spe_analysis.keys()]
data = [x for x in spe_analysis]

# %%
import pandas as pd

# write spe_analysis into pandas dataframe
spe_analysis_df = pd.DataFrame.from_records(data, columns=columns)
spe_analysis_df.head()
# Out:
#                sample_id        structure_id preferred_lcms_method spe_method  \
# 0  MTA0ST2022-051-001_S2  MTA0ST2022-051-001           Xbridge HpH        HLB
# 1  MTA0ST2022-051-003_G1  MTA0ST2022-051-003           Xbridge HpH        MCX
# 2     MTA0ST2022-051-004  MTA0ST2022-051-004            Gemini LpH        MCX
# 3     MTA0ST2022-051-005  MTA0ST2022-051-005            Gemini LpH        MCX
# 4     MTA0ST2022-051-006  MTA0ST2022-051-006           Xbridge HpH        MCX
#
#             method spe_successful crashed_out sample_status  \
# 0  HLB/Xbridge HpH           TRUE        None      Complete
# 1  MCX/Xbridge HpH           TRUE        None      Complete
# 2   MCX/Gemini LpH           TRUE        None      Complete
# 3   MCX/Gemini LpH           TRUE        None      Complete
# 4  MCX/Xbridge HpH           TRUE        None      Complete
#
#   sample_current_status termination_cause  ... NumAromaticHeterocycles  \
# 0    Completed & Stored              None  ...                       1
# 1    Completed & Stored              None  ...                       1
# 2    Completed & Stored              None  ...                       0
# 3    Completed & Stored              None  ...                       1
# 4    Completed & Stored              None  ...                       1
#
#   NumAromaticRings NumHAcceptors NumHDonors NumHeteroatoms NumRotatableBonds  \
# 0                2             4          2              9                 2
# 1                2             4          1              8                 2
# 2                2             3          1              6                 2
# 3                2             2          1              6                 2
# 4                3             2          1              6                 2
#
#   NumSaturatedCarbocycles NumSaturatedHeterocycles NumSaturatedRings RingCount
# 0                       0                        1                 1         3
# 1                       0                        1                 1         3
# 2                       0                        1                 1         3
# 3                       0                        1                 1         3
# 4                       0                        1                 1         4
#
# [5 rows x 65 columns]

# %%
spe_analysis_df.shape
# Out:
# (1086, 65)

# %%
# write spe_analysis into pandas dataframe
# spe_analysis_df.to_sql('spe_analysis', engine, if_exists='replace', index=False)
